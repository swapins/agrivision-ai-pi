# %% [markdown]
# # AgriVision AI — GPU training notebook
# This notebook trains MobileNetV2 for the Raspberry Pi + Coral project. Use the full dataset for release results; `--smoke` is only a pipeline check.

# %%
# !git clone YOUR_GITHUB_REPO_URL agrivision-ai-pi
# %cd agrivision-ai-pi
# !pip -q install -r training/requirements.txt

# %%
# !python training/train_tf_mobilenetv2.py --task binary

# %% [markdown]
# ## Output
# Download `training/output/agrivision-mobilenetv2/plant_health_int8.tflite`, `labels.txt`, and `model_manifest.json`. Compile the INT8 model with the Edge TPU Compiler on a supported x86-64 Linux environment.
